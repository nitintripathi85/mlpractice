# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

path = "/home/kuggi/Downloads/winequality-white.csv"

wineData = pd.read_csv(path, sep=";")
print(wineData.keys())
print(wineData.describe())
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# ...

# %% [markdown]
# # This is header
#
# Something on these lines.

# %%
wineData.iloc[:,[1,2]]
# Out:
#       volatile acidity  citric acid
# 0                 0.27         0.36
# 1                 0.30         0.34
# 2                 0.28         0.40
# 3                 0.23         0.32
# 4                 0.23         0.32
# ...                ...          ...
# 4893              0.21         0.29
# 4894              0.32         0.36
# 4895              0.24         0.19
# 4896              0.29         0.30
# 4897              0.21         0.38
#
# [4898 rows x 2 columns]

# %%
plt.hist(wineData["quality"])
plt.show()

# %%
plt.scatter(wineData["sulphates"],wineData["density"])
plt.show()

# %%
wineData.head()
wineData.shape #attribute and not a method
# wineData.info()
wineData.describe() #in this, count gives non missing values.
wineData.values #2d numpy array
wineData.columns
# wineData.index
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# wineData.sort_values("fixed acidity", ascending=False)
wineData.sort_values(["fixed acidity","citric acid"], ascending=[True,False])
wineData[wineData["quality"].isin([7])]
wineData.drop_duplicates
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 13              6.6              0.16         0.40             1.5      0.044
# 15              6.6              0.17         0.38             1.5      0.032
# 21              6.4              0.31         0.38             2.9      0.038
# 29              7.2              0.32         0.36             2.0      0.033
# 45              7.4              0.18         0.31             1.4      0.058
# ...             ...               ...          ...             ...        ...
# 4870            6.1              0.32         0.28             6.6      0.021
# 4876            6.2              0.38         0.42             2.5      0.038
# 4886            6.2              0.21         0.28             5.7      0.028
# 4887            6.2              0.41         0.22             1.9      0.023
# 4896            5.5              0.29         0.30             1.1      0.022
#
# ...
