# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/kuggi/Downloads/ca_san_francisco_2020_04_01.csv")

# %%
# df.info()
# pd.crosstab(df.subject_race,df.subject_sex).plot(kind="bar")
pd.crosstab(df.subject_race,df.subject_sex).plot(kind="barh", stacked=True)
plt.show()
